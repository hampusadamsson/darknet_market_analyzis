# %%
import pickle
from pprint import pprint
import matplotlib
import matplotlib.pyplot as plt

matplotlib.style.use("ggplot")
matplotlib.rcParams.update({'font.size': 13})

# %%
# dataset = pickle.load( open( "dataset_alphabay.p", "rb" ) )
# dataset = pickle.load( open( "dataset_silkroad.p", "rb" ) )
dataset = pickle.load( open( "dataset_poseidon.p", "rb" ) )

pprint(dataset[0].keys())
pprint(len(dataset)) # 8376 listings in dir
# Out:
# dict_keys(['description', 'category'])
# 3688

# %%
data=[]
for x in dataset:
    data.append(x.get("category"))
pprint(set(data))
# Out:
# {' Accounts',
#  ' Accounts & Bank Drops',
#  ' Benzos',
#  ' Buprenorphine',
#  ' Cannabis',
#  ' Carding',
#  ' Cocaine',
#  ' Codeine',
#  ' Concentrates',
#  ' Digital products',
#  ' Drugs',
#  ' Ecstasy',
#  ' Electronics',
#  ' Erotica',
#  ' Fraud',
#  ' Hacking',
#  ' Hash',
#  ' IT',
#  ' Info / Guides / eBooks',
#  ' MDMA',
#  ' Making money',
#  ' Money',
#  ' Mushrooms',
#  ' NB',
#  ' Non-lethal weapons',
#  ' Other',
#  ' Pills',
#  ' Pistols',
#  ' Prescription',
#  ' Security & Anonymity',
#  ' Security software',
#  ' Shake/trim',
#  ' Software',
#  ' Speed',
#  ' Stimulants',
#  ' Weed'}

# %%
print("CATEGORY")
print(dataset[153].get("category"))
print("\n")
print("DESCRIPTION")
print(dataset[153].get("description"))
# Out:
# CATEGORY
#  Money
#
#
# DESCRIPTION
#
#
#
# Poseidon Market
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Messages: 0
#
#
#  Orders: 0
#
#
#  Wallet:  0.00000000
#
#
#
#
#  simurgh
#
#
#  Support
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100% successful Bank transfers
#  etimbuk (0/5) 0 deals.
#  Add this item to Bookmarks
#
#
#
#  Category: Money
#
#
# 					Proven Secrets to Gain The Extra Edge and Make Money Fast to Generate $20 to $100 In A Matter of Minutes. Then The Best Part is All It Can Be Done Online and Offline and This Can Be Scaled As Much As You Want and You Will Have The Power to Run The Whole Show. Here You Will Have Bit Coin Foundation Fast Start with The Secrets of How BitCoin Works So You Can Gain The Extra Edge and Make Money Fast. Then You Will Also Learn How to Find Out How A BitCoin is Made And What You Need to In Order To Get a Ton Of Them Easily and Quickly. You Will Also Learn Why The $20 Bill in Your Pocket Right Now Is Worthless and What You Should Be Focused On Instead.
#
#
#
#
#
#
# Order
# Please read the product information carefully and be sure you agree all vendor's terms and conditions.
# 					Here you can set the number of this item you want to order. After you checkout you will be able to communicate with the vendor and set your details for receiving the items (digital or physical)
#
# 					Purchase price:
#  1
#  0.00445097
#
#
#
#
#
# Quantity (Unlimited available):
#
#
# Buy Now
#
#
#
#
#
#
#
#
#
# Feedbacks
#
#
#
#
# View more from this user
#
#
#
#
#
#
#
#
#
# Poseidon Market

# %%
data={}
for x in dataset:
    try:
        data[x.get("category")] += 1
    except:
        data[x.get("category")] = 0

d_key = [k for k in sorted(data, key=lambda k: data[k], reverse=True)]
d_val = [data.get(k) for k in d_key]
    
fig = matplotlib.pyplot.gcf()
fig.set_size_inches(18.5, 10.5)
plt.bar(range(len(data)), d_val, align='center')
plt.xticks(range(len(data)), d_key)
fig.autofmt_xdate()
plt.show()

# %%
data={}
for x in dataset:
    try:
        cat = x.get("category").split("/")[0]
        data[cat] += 1
    except:
        cat = x.get("category").split("/")[0]
        data[cat] = 0
        
d_key = [k for k in sorted(data, key=lambda k: data[k], reverse=True)]
d_val = [data.get(k) for k in d_key]
    
fig = matplotlib.pyplot.gcf()
fig.set_size_inches(16, 8)
plt.ylabel("Amount of web pages")
plt.xlabel("Product category")
plt.bar(range(len(data)), d_val, align='center')
plt.xticks(range(len(data)), d_key)
fig.autofmt_xdate()
plt.show()

# %%
from langdetect import detect,detect_langs
from tqdm import tqdm

data={}
for x in tqdm(dataset):
    try:
        cat = detect(x.get("description"))
        data[cat] += 1
    except:
        cat = detect(x.get("description"))
        data[cat] = 1
print(data) # ~90% english
# Out:
# 100%|██████████| 3688/3688 [00:28<00:00, 129.71it/s]
# {'en': 3688}

# %%
d_key = [k for k in sorted(data, key=lambda k: data[k], reverse=True)]
d_val = [data.get(k) for k in d_key]
    
fig = matplotlib.pyplot.gcf()
fig.set_size_inches(10, 5)
plt.bar(range(len(data)), d_val, align='center')
plt.xticks(range(len(data)), d_key)
fig.autofmt_xdate()
plt.show()
